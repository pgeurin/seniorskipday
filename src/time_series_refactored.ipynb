# %%
import autoregression

# %%
from autoregression import timeseries
# from autoregression.timeseries import plot_series_and_first_differences_over_bound_time
# Out:
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
timeseries.main()

# %%
posts_df = pd.read_csv('../data/posts.csv')

# %%
posts_df['date'] = pd.to_datetime(posts_df['date'], errors='coerce')
plot_series_and_first_differences_over_bound_time(posts_df, event_col_name='classroom_id', time_col_name='date', other_col_name='id', num=10, start=pd.to_datetime("2012"), stop=pd.to_datetime("2018"))
# plot_series_and_first_differences_over_bound_time(posts_df, event_col_name='classroom_id', time_col_name='date', other_col_name='id', num=10)
# plot_series_and_first_differences_over_bound_time(posts_df, event_col_name='classroom_id', time_col_name='date', other_col_name='id', num=10, start=pd.to_datetime("2016"), stop=pd.to_datetime("2018"))

# %%
count_posts_per_day_df = posts_df.groupby(['classroom_id', 'date']).count()

# %%
first_few_classrooms = list(count_posts_per_day_df.index.get_level_values(0).unique())[:3]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-2dea6e8a3f7c> in <module>()
#       1 posts_df['date'] = pd.to_datetime(posts_df['date'], errors='coerce')
#       2 # plot_series_and_first_differences_over_bound_time(posts_df, event_col_name='classroom_id', time_col_name='date', other_col_name='id', num=10, start=pd.to_datetime("2014"), stop=pd.to_datetime("2018"))
# ----> 3 plot_series_and_first_differences_over_bound_time(posts_df, event_col_name='classroom_id', time_col_name='date', other_col_name='id', num=10)
#       4 # plot_series_and_first_differences_over_bound_time(posts_df, event_col_name='classroom_id', time_col_name='date', other_col_name='id', num=10, start=pd.to_datetime("2016"), stop=pd.to_datetime("2018"))
#       5 count_posts_per_day_df = posts_df.groupby(['classroom_id', 'date']).count()
#
# ~/Dropbox/Galvanize/autoregression/autoregression/timeseries.py in plot_series_and_first_differences_over_bound_time(events_df, event_col_name, time_col_name, other_col_name, num, start, stop)
#      66         start = min(events_df[time_col_name])
#      67     if not stop:
# ---> 68         stop = max(events_df[time_col_name])
#      69     events_df[time_col_name] = pd.to_datetime(events_df[time_col_name], errors='coerce')
#      70     count_posts_per_day_df = events_df.groupby([event_col_name, time_col_name]).count()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/base.py in __iter__(self)
#     823         (for Timestamp/Timedelta/Interval/Period)
#     824         """
# --> 825         return iter(self.tolist())
#     826
#     827     @cache_readonly
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/base.py in tolist(self)
#     811
#     812         if is_datetimelike(self):
# --> 813             return [_maybe_box_datetimelike(x) for x in self._values]
#     814         else:
#     815             return self._values.tolist()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/base.py in <listcomp>(.0)
#     811
#     812         if is_datetimelike(self):
# --> 813             return [_maybe_box_datetimelike(x) for x in self._values]
#     814         else:
#     815             return self._values.tolist()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/common.py in _maybe_box_datetimelike(value)
#     172
#     173     if isinstance(value, (np.datetime64, datetime)):
# --> 174         value = tslib.Timestamp(value)
#     175     elif isinstance(value, (np.timedelta64, timedelta)):
#     176         value = tslib.Timedelta(value)
#
# KeyboardInterrupt:

# %%
for classroom_id in first_few_classrooms:
    print(classroom_id)
    class_n_count_posts_per_day = count_posts_per_day_df.loc[classroom_id]
    timeseries = pd.Series(class_n_count_posts_per_day['id'].values,
                           class_n_count_posts_per_day.index)
    timeseries = fill_and_float_timeseries(timeseries, freq='D')
    # timeseries = timestamp_events_to_timeseries(event_timestamp_df, event_col_name='classroom_id', time_col_name='date', other_col_na
    make_arema_prediction(timeseries)
# class_1_count_posts_per_day = count_posts_per_day_df.loc[1]
# timeseries = pd.Series(class_1_count_posts_per_day['id'].values,
#                        class_1_count_posts_per_day.index)
# timeseries = fill_and_float_timeseries(timeseries, freq='D')
# # timeseries = timestamp_events_to_timeseries(event_timestamp_df, event_col_name='classroom_id', time_col_name='date', other_col_na
# make_arema_prediction(timeseries)

# %%
classroom_stats = pd.read_csv('../data/classroom_stats.csv')

# %%
classroom_id=1

# %%
classroom_stat = classroom_stats.loc(int(classroom_id))

# %%
ls

# %%
classroom_stats['Probabilty Zero Posts for next 6 months'].apply(lambda x: str(round(x, 2)))
# Out:
# 0      0.77
# 1      0.75
# 2      0.75
# 3      0.73
# 4      0.73
# 5      0.68
# 6      0.63
# 7      0.62
# 8      0.62
# 9      0.61
# 10     0.61
# 11     0.61
# 12     0.61
# 13      0.6
# 14      0.6
# 15      0.6
# 16      0.6
# 17     0.59
# 18     0.58
# 19     0.58
# 20     0.58
# 21     0.58
# 22     0.58
# 23     0.57
# 24     0.57
# 25     0.57
# 26     0.57
# 27     0.57
# 28     0.57
# 29     0.56
#        ...
# 72      0.4
# 73     0.39
# 74     0.39
# 75     0.39
# 76     0.38
# 77     0.38
# 78     0.38
# 79     0.38
# 80     0.36
# 81     0.36
# 82     0.36
# 83     0.36
# 84     0.35
# 85     0.34
# 86     0.34
# 87     0.34
# 88     0.33
# 89     0.33
# 90     0.32
# 91     0.32
# 92     0.32
# 93     0.32
# 94     0.31
# 95     0.28
# 96     0.25
# 97     0.25
# 98     0.24
# 99      0.2
# 100     0.2
# 101     0.2
# Name: Probabilty Zero Posts for next 6 months, Length: 102, dtype: object

# %%
classroom_stats.rename(columns={'Probabilty Zero Posts for next 6 months': 'Prob 0 posts 6 months', 'post_per_lesson_aka_popularity_mean': 'Lesson Popularity', "classroom_id": "Classroom ID", 'school_id_unique': 'School ID'})
# Out:
#      Classroom ID  Prob 0 posts 6 months  School ID  school_id_mean  \
# 0             248               0.772537         78              78
# 1             350               0.754907        107             107
# 2              80               0.754907         45              45
# 3            1124               0.732055        217             217
# 4             321               0.732055         81              81
# 5             184               0.683784         21              21
# 6            1435               0.625797        460             460
# 7             950               0.621386        160             160
# 8            2023               0.621386        748             748
# 9            1161               0.613400         14              14
# 10            542               0.606350        219             219
# 11            268               0.606232         84              84
# 12           1551               0.606232        461             461
# ...
